# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ----------
# anyio                     4.6.2
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# asttokens                 2.4.0
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# backcall                  0.2.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# Brotli                    1.0.9
# certifi                   2024.12.14
# cffi                      1.17.1
# charset-normalizer        3.3.2
# colorama                  0.4.6
# comm                      0.1.4
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 1.2.0
# fastjsonschema            2.20.0
# h11                       0.14.0
# httpcore                  1.0.2
# httpx                     0.27.0
# idna                      3.7
# ipykernel                 6.25.2
# ...

# %%
# !pip install pandas numpy matplotlib statsmodels scipy scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.6 MB 9.1 MB/s eta 0:00:02
#    ------------- -------------------------- 3.9/11.6 MB 9.4 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.6 MB 9.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.9/11.6 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.0/11.6 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 8.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/12.9 MB 8.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/12.9 MB 8.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.9 MB 8.8 MB/s eta 0:00:01
# ...
